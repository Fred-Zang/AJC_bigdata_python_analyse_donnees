# %% [markdown]
# # 06 - Pandas (les Bases) => Analyse du Titanic

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# pip install pandas si en local avec IED et environnement créé

# 📌 Pour Google Colab : importer manuellement un fichier local (ex: titanic.xlsx)
from google.colab import files

# Ouvre une boîte de dialogue pour que l'étudiant sélectionne le fichier depuis son ordi
uploaded = files.upload()  # Charger manuellement le fichier titanic.xlsx

# %% [markdown]
# ## 1. Charger et voir données dans un DataFrame Pandas
# ###    chaque cellule est définie par un Name (titre colonne ) et un index (n° de ligne de 0 à n)
#
# Les options les plus courantes :
# - read_csv   read_json   read_html
# - read_excel read_sql

# %%
data_origin = pd.read_excel('titanic.xlsx')  # on charge le fichier xls dans un dataframe tableau panda (panda peut tout lire et passer en dataframe )

# %%
data_origin.sample(10)
# Out:
#       pclass  survived                                               name  \
# 273        1         1                    Spedden, Master. Robert Douglas
# 714        3         1                                    Chip, Mr. Chang
# 583        2         1  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...
# 1051       3         0                       Nancarrow, Mr. William Henry
# 863        3         0                             Hendekovic, Mr. Ignjac
# 12         1         1                      Aubart, Mme. Leontine Pauline
# 124        1         1  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...
# 214        1         1                             Newell, Miss. Marjorie
# 885        3         0                          Jensen, Mr. Svend Lauritz
# 1069       3         0                                O'Brien, Mr. Thomas
#
#          sex   age  sibsp  parch      ticket      fare cabin embarked boat  \
# 273     male   6.0      0      2       16966  134.5000   E34        C    3
# ...

# %%
print(data_origin.shape)
data_origin.sample(10)  # affiche tête de data et 1eres lignes

# df.head(15)
# df.tail(20)
# Out:
# (1309, 14)
#      pclass  survived                                               name  \
# 779       3         0                             Doyle, Miss. Elizabeth
# 56        1         1                         Carter, Mr. William Ernest
# 840       3         0                                Haas, Miss. Aloisia
# 315       1         1                           Willard, Miss. Constance
# 179       1         0                                 Klaber, Mr. Herman
# 461       2         0                            Jarvis, Mr. John Denzil
# 245       1         1  Rothes, the Countess. of (Lucy Noel Martha Dye...
# 755       3         0                                 Davies, Mr. Joseph
# 642       3         0                       Asplund, Master. Filip Oscar
# 366       2         0                      Carter, Rev. Ernest Courtenay
#
#         sex   age  sibsp  parch     ticket      fare    cabin embarked  boat  \
# ...

# %%
data_origin.describe() # donne tableau infos de bases ( total éléments/colonne - moyenne - min - max - std - quartiles 25% 50% 75% )
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
data_origin.info() # donne les Nan et types de colonnes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %% [markdown]
# ## 2. Nettoyer avec drop(), dropna() - Compter avec value_counts()

# %%
data = data_origin.drop(['name', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'], axis=1)  # élimine les colonnes 
# axis=0 pour les lignes et axis=1 pour les colonnes

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.sample(10)
# Out:
#       pclass  survived     sex   age
# 859        3         0  female  18.0
# 954        3         0    male   NaN
# 1235       3         0    male  74.0
# 1225       3         0    male  60.5
# 1248       3         0    male  32.0
# 308        1         1  female  55.0
# 289        1         1  female  18.0
# 449        2         1  female  54.0
# 291        1         1  female  39.0
# 425        2         0    male  52.0

# %%
data_origin[['age', 'sex']]
# Out:
#           age     sex
# 0     29.0000  female
# 1      0.9167    male
# 2      2.0000  female
# 3     30.0000    male
# 4     25.0000  female
# ...       ...     ...
# 1304  14.5000  female
# 1305      NaN  female
# 1306  26.5000    male
# 1307  27.0000    male
# 1308  29.0000    male
#
# [1309 rows x 2 columns]

# %%
data_origin['age']
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
data2 = data_origin[['pclass', 'survived', 'sex', 'age']] # autre possibilité : on garde ces colonnes au lieu d'éliminer

# %%
data2.head()  # tester data.tail(8) - data.sample(5) - data.sample(frac=0.1) pour 10% aléatoire
# Out:
#    pclass  survived     sex      age
# 0       1         1  female  29.0000
# 1       1         1    male   0.9167
# 2       1         0  female   2.0000
# 3       1         0    male  30.0000
# 4       1         0  female  25.0000

# %%
data.info()   # on voit qu'il manque des données pour 'age' car 1046 au lieu de 1309
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   survived  1309 non-null   int64
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 41.0+ KB

# %% [markdown]
# ![image.png](attachment:0cadcc53-9993-4ae8-8488-2dc7e5cb9925.png)

# %% [markdown]
# ![image.png](attachment:e82cb7e1-fc3d-423f-93bc-e92b7efa9486.png)

# %% [markdown]
# ![image.png](attachment:1999841e-326f-40e8-9db8-e837c2e7ff28.png)

# %%
data.dropna(axis=0, inplace=True)  # élimine les lignes axis=0 où nan est présent
data.shape  # vérif élimination lignes
# Out:
# (1046, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1046 entries, 0 to 1308
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1046 non-null   int64
#  1   survived  1046 non-null   int64
#  2   sex       1046 non-null   object
#  3   age       1046 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 40.9+ KB

# %%
data.dropna(axis=0, inplace=True)
data.shape
# Out:
# (1046, 4)

# %%
counts_reset = data.reset_index()
counts_reset
# Out:
#       index  pclass  survived     sex      age
# 0         0       1         1  female  29.0000
# 1         1       1         1    male   0.9167
# 2         2       1         0  female   2.0000
# 3         3       1         0    male  30.0000
# 4         4       1         0  female  25.0000
# ...     ...     ...       ...     ...      ...
# 1041   1301       3         0    male  45.5000
# 1042   1304       3         0  female  14.5000
# 1043   1306       3         0    male  26.5000
# 1044   1307       3         0    male  27.0000
# 1045   1308       3         0    male  29.0000
#
# [1046 rows x 5 columns]

# %%
data[['pclass', 'age']].value_counts().reset_index()
# Out:
#      pclass   age  count
# 0         3  22.0     30
# 1         3  21.0     28
# 2         3  18.0     24
# 3         3  24.0     22
# 4         3  26.0     20
# ..      ...   ...    ...
# 204       3  61.0      1
# 205       3  63.0      1
# 206       3  65.0      1
# 207       3  70.5      1
# 208       3  74.0      1
#
# [209 rows x 3 columns]

# %%
data['age'].value_counts()

# %%
data['pclass'].value_counts().plot.bar() # plot.bar() ici est une méthodes native de pandas mais reposant sur matplotlib
# Out:
# <Axes: xlabel='pclass'>

# %%
data['age'].hist() # hist() ici est une méthodes native de pandas mais reposant sur matplotlib

# %% [markdown]
# ### PS : si on voulait utiliser matplotlib, ce serait plus joli et modifiable en graph mais plus complexe à coder

# %%
import matplotlib.pyplot as plt

# Créer la figure et les axes
plt.figure(figsize=(10, 6))

# Tracer l'histogramme
plt.hist(data['age'].dropna(), bins=30, edgecolor='black')

# Ajouter un titre et des labels aux axes
plt.title('Répartition des âges', fontsize=14)
plt.xlabel('Âge', fontsize=12)
plt.ylabel('Fréquence', fontsize=12)

# Afficher le graphique
plt.show()

# %% [markdown]
# ## 3. Groupby() et value_counts()

# %%
data.groupby(['sex']).mean()  # regrouper le dataframe par 'sex' Et faire la moyenne mean() - pclass=1, 2, 3 mean(pclass) peu utile

# %%
data.groupby(['sex', 'pclass']).mean()  # ce regroupement est mieux ! moyenne par sex et par class

# %%
data['pclass'].value_counts()

# %%
print(data['age'] < 18)
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 1301    False
# 1304     True
# 1306    False
# 1307    False
# 1308    False
# Name: age, Length: 1046, dtype: bool

# %%
data[data['age'] >= 18]
# Out:
#       pclass  survived     sex   age
# 0          1         1  female  29.0
# 3          1         0    male  30.0
# 4          1         0  female  25.0
# 5          1         1    male  48.0
# 6          1         1  female  63.0
# ...      ...       ...     ...   ...
# 1299       3         0    male  27.0
# 1301       3         0    male  45.5
# 1306       3         0    male  26.5
# 1307       3         0    male  27.0
# 1308       3         0    male  29.0
#
# [892 rows x 4 columns]

# %%
data[data['age'] < 18]['pclass'].value_counts()

# %%
data[data['age'] < 18].groupby(['sex', 'pclass']).mean()  # GENIAL D ENCHAINER AINSI LES COMMANDES !!
# Out:
#                survived        age
# sex    pclass
# female 1       0.875000  14.125000
#        2       1.000000   8.273150
#        3       0.543478   8.416667
# male   1       0.857143   9.845243
#        2       0.733333   6.222220
#        3       0.233333   9.838888

# %%
data.iloc[0:5, 0:4]
# Out:
#    pclass  survived     sex      age
# 0       1         1  female  29.0000
# 1       1         1    male   0.9167
# 2       1         0  female   2.0000
# 3       1         0    male  30.0000
# 4       1         0  female  25.0000

# %%
data.loc[:,'age']
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1301    45.5000
# 1304    14.5000
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1046, dtype: float64

# %%
data.info()  # rien de la dataframe data n'a été détruit ! ( sauf à faire data = data...)

# %% [markdown]
# ![image.png](attachment:3791e627-df76-43e0-9188-75eaa4c4c443.png)

# %% [markdown]
# ![image.png](attachment:fd616bac-c5bb-4790-96d5-c1784c7e6313.png)

# %% [markdown]
# ![image.png](attachment:1e49e31d-cccf-43b0-9f07-8cf981803666.png)

# %% [markdown]
# ![image.png](attachment:4c505b9b-4aa6-44c7-8aed-411af090f7c2.png)

# %% [markdown]
# ![image.png](attachment:63fe4a25-9013-4cc0-a753-0eabff4945c7.png)

# %% [markdown]
# ![image.png](attachment:11162f93-ac5b-44d2-a5be-6996629c94c6.png)

# %% [markdown]
# ![image.png](attachment:d1116c5e-3077-4d22-8607-06a1250e3156.png)
